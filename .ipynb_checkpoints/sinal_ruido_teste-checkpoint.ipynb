# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import time
import statsmodels
import statsmodels.api as sm
import seaborn as sns
from sklearn.metrics import mean_squared_error
from statsmodels.stats.stattools import jarque_bera
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.seasonal import seasonal_decompose
import datetime
# %matplotlib inline
from pmdarima.arima import auto_arima
import numpy as np
import matplotlib.pyplot as plt
import numpy.random

# %autocall
# Out:
# Automatic calling is: Smart

# %%
# sinal moificado para o tamanho da série temporal de temp global média(1644):
t  = np.linspace(0, 240,1644)

# %%
sinal = .2*np.exp(t/100) + np.sin(2*np.pi*t/3.) + .8 * np.sin(2*np.pi*t/45.)  + 6 * numpy.random.random(size=1644)

# %%
plt.plot(t,sinal)

# %%
f = np.fft.fftfreq(1000)
plt.plot(abs( np.fft.fftshift( np.fft.fft(sinal)) ) )
plt.semilogy()
# Out:
# []

# %%
# Carregando os dados:
df=pd.read_csv('global_temp_monthly.csv')

# Carregando os dados:

df_temp=df.dropna()
df_temp= df_temp.set_index(['Date'])

df_temp.index = pd.to_datetime(df_temp.index, format='%Y-%m')
df_temp = df_temp[['Mean']].groupby('Date').sum()
df_temp.rename(columns={'Mean': 'Temperature'}, inplace = True)

df_temp.head(10)
# Out:
#             Temperature
# Date
# 1880-01-01      -0.2991
# 1880-02-01      -0.3329
# 1880-03-01      -0.3157
# 1880-04-01      -0.3199
# 1880-05-01      -0.2138
# 1880-06-01      -0.4592
# 1880-07-01      -0.3891
# 1880-08-01      -0.1525
# 1880-09-01      -0.2517
# 1880-10-01      -0.3386

# %%
df_temp.describe()
# Out:
#        Temperature
# count  1644.000000
# mean      0.073177
# std       0.667436
# min      -1.369600
# 25%      -0.420550
# 50%      -0.072400
# 75%       0.477025
# max       2.542100

# %%
ruido= df_temp[['Temperature']].values + sinal

# %%
df_temp[['Temperature']].values
# Out:
# array([[-0.2991],
#        [-0.3329],
#        [-0.3157],
#        ...,
#        [ 1.6192],
#        [ 1.6804],
#        [ 1.5995]])

# %%
ruido
# Out:
# array([[2.36400472, 3.38441937, 3.78871476, ..., 5.07815113, 2.84366538,
#         6.84717035],
#        [2.33020472, 3.35061937, 3.75491476, ..., 5.04435113, 2.80986538,
#         6.81337035],
#        [2.34740472, 3.36781937, 3.77211476, ..., 5.06155113, 2.82706538,
#         6.83057035],
#        ...,
#        [4.28230472, 5.30271937, 5.70701476, ..., 6.99645113, 4.76196538,
#         8.76547035],
#        [4.34350472, 5.36391937, 5.76821476, ..., 7.05765113, 4.82316538,
#         8.82667035],
#        [4.26260472, 5.28301937, 5.68731476, ..., 6.97675113, 4.74226538,
#         8.74577035]])

# %%
data_ruido=pd.DataFrame(ruido)

# %%
data_ruido
# Out:
#           0         1         2         3         4        5         6     \
