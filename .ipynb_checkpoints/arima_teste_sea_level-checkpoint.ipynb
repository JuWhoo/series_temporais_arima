# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import time
import statsmodels
import statsmodels.api as sm
import seaborn as sns
from sklearn.metrics import mean_squared_error
from statsmodels.stats.stattools import jarque_bera
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.seasonal import seasonal_decompose
import datetime
# %matplotlib inline
from pmdarima.arima import auto_arima

# %%
# Carregando os dados:
df=pd.read_csv('sea_level.csv')

# Carregando os dados:

df_sea=df.dropna()
df_sea= df_sea.set_index(['Year'])

df_sea.index = pd.to_datetime(df_sea.index, format='%Y')
df_sea = df_sea[['Sea Level']].groupby('Year').sum()
df_sea.rename(columns={'Sea Level': 'Temperature'}, inplace = True)

df_temp.head(10)
# Out:
#             Temperature
# Date
# 1880-01-01      -0.2991
# 1880-02-01      -0.3329
# 1880-03-01      -0.3157
# 1880-04-01      -0.3199
# 1880-05-01      -0.2138
# 1880-06-01      -0.4592
# 1880-07-01      -0.3891
# 1880-08-01      -0.1525
# 1880-09-01      -0.2517
# 1880-10-01      -0.3386

# %%
df_temp.iloc[[0, -1]]
# Out:
#             Temperature
# Date
# 1880-01-01      -0.2991
# 2016-12-01       1.5995

# %%
# conhecendo os dados:
df_temp.head(10)
# Out:
#             Temperature
# Date
# 1880-01-01      -0.2991
# 1880-02-01      -0.3329
# 1880-03-01      -0.3157
# 1880-04-01      -0.3199
# 1880-05-01      -0.2138
# 1880-06-01      -0.4592
# 1880-07-01      -0.3891
# 1880-08-01      -0.1525
# 1880-09-01      -0.2517
# 1880-10-01      -0.3386

# %%
# conhecendo os dados:
df_temp.tail(12)
# Out:
#             Temperature
# Date
# 2016-01-01       2.2269
# 2016-02-01       2.5421
# 2016-03-01       2.5245
# 2016-04-01       2.1633
# 2016-05-01       1.8038
# 2016-06-01       1.6606
# 2016-07-01       1.6987
# 2016-08-01       1.8798
# 2016-09-01       1.7467
# 2016-10-01       1.6192
# 2016-11-01       1.6804
# 2016-12-01       1.5995

# %%
# conhecendo os dados:
df_temp.info()
df_temp.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1644 entries, 1880-01-01 to 2016-12-01
# Data columns (total 1 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Temperature  1644 non-null   float64
# dtypes: float64(1)
# memory usage: 25.7 KB
#        Temperature
# count  1644.000000
# mean      0.073177
# std       0.667436
# min      -1.369600
# 25%      -0.420550
# 50%      -0.072400
# 75%       0.477025
# max       2.542100

# %%
# decompondo a série

seasonplot = seasonal_decompose(df_temp)
fig, (ax1, ax2, ax3, ax4) = plt.subplots(4, 1, figsize=(15,8))
seasonplot.observed.plot(ax=ax1, ylabel='Observações') 
seasonplot.trend.plot(ax=ax2, ylabel='Tendência') 
seasonplot.seasonal.plot(ax=ax3, ylabel='Sazonalidade')
seasonplot.resid.plot(ax=ax4, ylabel='Ruído') 
plt.tight_layout()

# %%
# aplicando o teste Dickey-Fuller Aumentado (ADF) para verificar estacionariedade na série:

# Extraindo a coluna que contém os dados da série temporal
dados_serie = df_temp['Temperature']
resultado_adf = adfuller(dados_serie)

# Extraindo os resultados do teste ADF
valor_p = resultado_adf[1]
estatistica_teste = resultado_adf[0]

# Comparando o valor-p com um nível de significância (geralmente 0.05)
nivel_de_significancia = 0.05

if valor_p <= nivel_de_significancia:
    print("A série temporal é estacionária (rejeita-se a hipótese nula).")
else:
    print("A série temporal não é estacionária (não se rejeita a hipótese nula).")

# Exiba a estatística do teste
print(f"Estatística do teste ADF: {estatistica_teste}")
print(f"Valor-p: {valor_p}")
# Out:
# A série temporal não é estacionária (não se rejeita a hipótese nula).
# Estatística do teste ADF: -0.4253688540073227
# Valor-p: 0.9057761439235807

# %%
# em caso negativo, para teste do melhor resultado da série para se tornar estacionária, pode ser aplicado a diferenciação:
diff_1 = dados_serie.diff().dropna()
# testar novamente por ADF

# %%
# verificando autocorrelação e autocorrelação parcial:
# auto-regressão (p) = autorrelação; média móvel (q)= autocorrelação parcial.
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(15,10))
sm.graphics.tsa.plot_acf(df_temp.values.squeeze(), lags=40, ax=ax1)
sm.graphics.tsa.plot_pacf(df_temp.values.squeeze(), lags= 40, ax=ax2, method='ywm')
plt.show()

# %%
# Aplicando método Auto ARIMA (já pode-se definir max e min valores dos parâmetros para facilitar o código):
# A sazonalidade, se mensal, usar m=12; Por padrão o P iniciará em 0 e o máximo será 2; o Q por padrão será 1 e o máximo, por padrão, será 2; o d será 1 e o máximo, por padrão, será 2; o D será 1, por padrão já é 1.
# Serão gerados vários modelos ARIMA e os seus respectivos AIC's e BICS (critérios de informação).
# Stepwise permite diminuir o número de modelos gerados, deixa o código mais leve.
stepwise=auto_arima(df_temp,start_p=0, start_q=0,max_p=3,max_q=3,m=12,start_P=0,
                     seasonal=True,trace=True, error_action='ignore',suppress_warnings=True, stepwise=True)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(0,0,1)[12] intercept   : AIC=-342.386, Time=0.90 sec
#  ARIMA(0,1,0)(0,0,0)[12] intercept   : AIC=-343.023, Time=0.21 sec
#  ARIMA(1,1,0)(1,0,0)[12] intercept   : AIC=-552.569, Time=0.74 sec
#  ARIMA(0,1,1)(0,0,1)[12] intercept   : AIC=-638.690, Time=1.35 sec
#  ARIMA(0,1,0)(0,0,0)[12]             : AIC=-344.977, Time=0.12 sec
#  ARIMA(0,1,1)(0,0,0)[12] intercept   : AIC=-639.332, Time=0.50 sec
#  ARIMA(0,1,1)(1,0,0)[12] intercept   : AIC=-638.982, Time=1.18 sec
#  ARIMA(0,1,1)(1,0,1)[12] intercept   : AIC=-657.392, Time=3.74 sec
#  ARIMA(0,1,1)(2,0,1)[12] intercept   : AIC=-658.026, Time=14.80 sec
#  ARIMA(0,1,1)(2,0,0)[12] intercept   : AIC=-656.088, Time=6.64 sec
#  ARIMA(0,1,1)(2,0,2)[12] intercept   : AIC=-661.674, Time=19.45 sec
#  ARIMA(0,1,1)(1,0,2)[12] intercept   : AIC=-657.656, Time=18.53 sec
#  ARIMA(0,1,0)(2,0,2)[12] intercept   : AIC=-356.329, Time=11.42 sec
#  ARIMA(1,1,1)(2,0,2)[12] intercept   : AIC=-680.624, Time=22.22 sec
#  ARIMA(1,1,1)(1,0,2)[12] intercept   : AIC=-673.863, Time=20.33 sec
#  ARIMA(1,1,1)(2,0,1)[12] intercept   : AIC=-676.135, Time=18.26 sec
#  ARIMA(1,1,1)(1,0,1)[12] intercept   : AIC=-674.506, Time=8.05 sec
#  ARIMA(1,1,0)(2,0,2)[12] intercept   : AIC=-570.090, Time=10.35 sec
#  ARIMA(2,1,1)(2,0,2)[12] intercept   : AIC=-692.850, Time=25.73 sec
#  ARIMA(2,1,1)(1,0,2)[12] intercept   : AIC=-690.519, Time=22.57 sec
#  ARIMA(2,1,1)(2,0,1)[12] intercept   : AIC=-692.288, Time=23.38 sec
#  ARIMA(2,1,1)(1,0,1)[12] intercept   : AIC=-685.883, Time=9.86 sec
#  ARIMA(2,1,0)(2,0,2)[12] intercept   : AIC=-619.063, Time=23.58 sec
#  ARIMA(3,1,1)(2,0,2)[12] intercept   : AIC=-697.757, Time=28.74 sec
#  ARIMA(3,1,1)(1,0,2)[12] intercept   : AIC=-701.039, Time=29.04 sec
#  ARIMA(3,1,1)(0,0,2)[12] intercept   : AIC=-701.952, Time=22.71 sec
#  ARIMA(3,1,1)(0,0,1)[12] intercept   : AIC=-689.297, Time=10.04 sec
#  ARIMA(3,1,1)(1,0,1)[12] intercept   : AIC=-703.629, Time=16.69 sec
#  ARIMA(3,1,1)(1,0,0)[12] intercept   : AIC=-690.638, Time=11.62 sec
#  ARIMA(3,1,1)(2,0,1)[12] intercept   : AIC=-694.457, Time=25.84 sec
#  ARIMA(3,1,1)(0,0,0)[12] intercept   : AIC=-688.931, Time=1.29 sec
#  ARIMA(3,1,1)(2,0,0)[12] intercept   : AIC=-702.803, Time=22.09 sec
#  ARIMA(3,1,0)(1,0,1)[12] intercept   : AIC=-648.528, Time=8.69 sec
#  ARIMA(3,1,2)(1,0,1)[12] intercept   : AIC=inf, Time=10.82 sec
#  ARIMA(2,1,0)(1,0,1)[12] intercept   : AIC=-616.223, Time=5.12 sec
#  ARIMA(2,1,2)(1,0,1)[12] intercept   : AIC=-676.764, Time=10.41 sec
#  ARIMA(3,1,1)(1,0,1)[12]             : AIC=-704.080, Time=4.73 sec
#  ARIMA(3,1,1)(0,0,1)[12]             : AIC=-688.519, Time=2.32 sec
#  ARIMA(3,1,1)(1,0,0)[12]             : AIC=-689.087, Time=2.32 sec
#  ARIMA(3,1,1)(2,0,1)[12]             : AIC=-702.747, Time=10.73 sec
#  ARIMA(3,1,1)(1,0,2)[12]             : AIC=-702.646, Time=13.33 sec
#  ARIMA(3,1,1)(0,0,0)[12]             : AIC=-687.678, Time=0.55 sec
#  ARIMA(3,1,1)(0,0,2)[12]             : AIC=-700.403, Time=5.79 sec
#  ARIMA(3,1,1)(2,0,0)[12]             : AIC=-702.351, Time=6.52 sec
#  ARIMA(3,1,1)(2,0,2)[12]             : AIC=-706.061, Time=13.91 sec
#  ARIMA(2,1,1)(2,0,2)[12]             : AIC=-696.654, Time=12.33 sec
#  ARIMA(3,1,0)(2,0,2)[12]             : AIC=inf, Time=15.11 sec
#  ARIMA(3,1,2)(2,0,2)[12]             : AIC=-692.540, Time=14.63 sec
#  ARIMA(2,1,0)(2,0,2)[12]             : AIC=-621.079, Time=8.49 sec
#  ARIMA(2,1,2)(2,0,2)[12]             : AIC=-683.510, Time=11.98 sec
#
# Best model:  ARIMA(3,1,1)(2,0,2)[12]
# Total fit time: 589.803 seconds

# %%
# verificando resultado e menor AIC:
stepwise
# Out:
# ARIMA(order=(3, 1, 1), scoring_args={}, seasonal_order=(2, 0, 2, 12),
#       suppress_warnings=True, with_intercept=False)

# %%
stepwise.aic()
# Out:
# -706.0613490551434

# %%
# testando mais um modelo, com parâmetro diferente, por exemplo de sazonalidade D:
stepwise1=auto_arima(df_temp,start_p=0, start_q=0,max_p=3,max_q=2,start_P=0,
                     seasonal=False,trace=True,error_action='ignore',suppress_warnings=True,stepwise=True)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=-343.023, Time=0.19 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=-552.861, Time=0.11 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=-639.332, Time=0.48 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=-344.977, Time=0.09 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=-662.507, Time=0.83 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=-683.252, Time=1.30 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=-598.718, Time=0.13 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=-688.931, Time=0.86 sec
#  ARIMA(3,1,0)(0,0,0)[0] intercept   : AIC=-630.406, Time=0.25 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=-680.125, Time=1.26 sec
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=-684.408, Time=1.21 sec
#  ARIMA(3,1,1)(0,0,0)[0]             : AIC=-687.678, Time=0.28 sec
#
# Best model:  ARIMA(3,1,1)(0,0,0)[0] intercept
# Total fit time: 6.998 seconds

# %%
# verificando demais resultados com menores AIC:
stepwise1
stepwise1.aic()
# Out:
# -688.9309238586609

# %%
# validar modelo
# separando os dados de treino e teste: os dados de treino (70% inicial da amostra) serão usado para treinar o modelo ARIMA e os dados de teste(30% restante) para comparar com as previsões geradas.

train=df_temp.loc['1880-01-01':'2016-01-01']
test=df_temp.loc['2016-02-01':]

# %%
stepwise.fit(train)
# Out:
# ARIMA(order=(3, 1, 1), scoring_args={}, seasonal_order=(2, 0, 2, 12),
#       suppress_warnings=True, with_intercept=False)

# %%
stepwise1.fit(train)
# Out:
# ARIMA(order=(3, 1, 1), scoring_args={}, suppress_warnings=True)

# %%
# calculando previsões para n periodos futuros:
future_forecast=stepwise.predict(n_periods=24)

# %%
future_forecast1=stepwise1.predict(n_periods=24)

# %%
future_forecast=pd.DataFrame(future_forecast,index=test.index, columns=['previsão modelo 1'])

# %%
future_forecast1=pd.DataFrame(future_forecast1,index=test.index, columns=['previsão modelo 2'])

# %%
future_forecast.head(10)
# Out:
#             previsão modelo 1
# Date
# 2016-02-01           2.024657
# 2016-03-01           2.046273
# 2016-04-01           1.972609
# 2016-05-01           1.919543
# 2016-06-01           1.845261
# 2016-07-01           1.784577
# 2016-08-01           1.788376
# 2016-09-01           1.780501
# 2016-10-01           1.773120
# 2016-11-01           1.740773

# %%
future_forecast1.head(10)
# Out:
#             previsão modelo 2
# Date
# 2016-02-01           2.058431
# 2016-03-01           1.993311
# 2016-04-01           1.933039
# 2016-05-01           1.880207
# 2016-06-01           1.839682
# 2016-07-01           1.806766
# 2016-08-01           1.780200
# 2016-09-01           1.758947
# 2016-10-01           1.741932
# 2016-11-01           1.728359

# %%
plt.figure(figsize=(20,5))
pd.concat([test,future_forecast, future_forecast1],axis=1).plot(figsize=(20,5))
plt.xlabel('')
plt.title('Previsões X Real',size=15)
plt.legend(['Valor real','previsão 1'])
plt.show();

# %%
pd.concat([df_temp,future_forecast],axis=1).plot(linewidth=1,figsize=(20,5))
plt.legend('')
plt.xlabel('')
plt.title('Previsões X Real',size=15)
plt.show();

# %%
pd.concat([df_temp,future_forecast1],axis=1).plot(linewidth=1, figsize=(20,5))
plt.legend('')
plt.xlabel('')
plt.title('Previsões X Real',size=15)
plt.show();

# %%
# função para calcular o erro dos modelos
from math import sqrt
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_error

def check_erro(orig, prev, nome_col='', nome_indice=''):
    
    vies = np.mean(orig - prev)
    mse = mean_squared_error(orig, prev)
    rmse = sqrt(mean_squared_error(orig, prev))
    mae = mean_absolute_error(orig, prev)
    mape = np.mean(np.abs((orig - prev) / orig)) * 100
    
    grupo_erro = [vies, mse, rmse, mae, mape]
    serie = pd.DataFrame(grupo_erro, index=['VIÉS','MSE','RMSE','MAE', 'MAPE'], columns=[nome_col])
    serie.index.name = nome_indice
    
    return serie

# %%
# Análise dos erros/resíduos, ideal é o mais próximo de zero
check_erro(test,future_forecast)
# Out:
#
#
# VIÉS       NaN
# MSE   0.057658
# RMSE  0.240122
# MAE   0.182797
# MAPE       NaN

# %%
check_erro(test,future_forecast1)
# Out:
#
#
# VIÉS       NaN
# MSE   0.060007
# RMSE  0.244964
# MAE   0.182663
# MAPE       NaN

# %%
erros=pd.DataFrame(np.array(future_forecast.values.tolist())-np.array(test.values.tolist()))

erros1=pd.DataFrame(np.array(future_forecast1.values.tolist())-np.array(test.values.tolist()))

# %%
fig, ax = plt.subplots(1,2,figsize=(20,5))
sns.distplot(erros,ax=ax[0])
sns.distplot(erros1,ax=ax[1], color='red');

# %%
stepwise.plot_diagnostics(figsize=(10,6));

# %%
stepwise1.plot_diagnostics(figsize=(10,6));

# %%
# Verificado normalidade dos resíduos pelo teste Jarque Bera:
test = jarque_bera(erros)
print('Estatística Jarque-Bera :', test[0])
print('p-valor :', test[1])
print('Assimetria :', test[2])
print('Curtose :',test[3])
# Out:
# Estatística Jarque-Bera : [2.10384127]
# p-valor : [0.34926629]
# Assimetria : [-1.05623143]
# Curtose : [2.64264896]

# %%
test1 = jarque_bera(erros1)
print('Estatística Jarque-Bera :', test1[0])
print('p-valor :', test1[1])
print('Assimetria :', test1[2])
print('Curtose :',test1[3])
# Out:
# Estatística Jarque-Bera : [1.96937396]
# p-valor : [0.37355614]
# Assimetria : [-1.00978864]
# Curtose : [2.532963]

# %%
stepwise1.fit(df_temp)
# Out:
# ARIMA(order=(3, 1, 1), scoring_args={}, suppress_warnings=True)

# %%
future_forecast2=stepwise.predict(n_periods=48)

# %%
uture_forecast2=pd.DataFrame(future_forecast2, 
                              index=pd.date_range(start='2017-01-01',
                                                  end='2021-01-01'),columns=['Nova previsão'])

# %%
future_forecast2.head(24)
# Out:
# 2016-02-01    2.024657
# 2016-03-01    2.046273
# 2016-04-01    1.972609
# 2016-05-01    1.919543
# 2016-06-01    1.845261
# 2016-07-01    1.784577
# 2016-08-01    1.788376
# 2016-09-01    1.780501
# 2016-10-01    1.773120
# 2016-11-01    1.740773
# 2016-12-01    1.698108
# 2017-01-01    1.710350
# 2017-02-01    1.681622
# 2017-03-01    1.708059
# 2017-04-01    1.672437
# 2017-05-01    1.678300
# 2017-06-01    1.670023
# 2017-07-01    1.648700
# 2017-08-01    1.666927
# 2017-09-01    1.679247
# 2017-10-01    1.701048
# 2017-11-01    1.696978
# 2017-12-01    1.691088
# 2018-01-01    1.683339
# Freq: MS, dtype: float64

# %%
plt.figure(figsize=(20,5))
pd.concat([df_temp,future_forecast2],axis=1).plot(figsize=(20,5))
plt.xlabel('')
plt.title('Série total e novas previsões',size=15)
plt.legend(['Série total','Previsões'])
plt.show();
